# %%
#Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read dataset

Sentencing_Data = pd.read_csv('/Users/drewbrinda/Desktop/Sentencing.csv')
Intake_Data = pd.read_csv('/Users/drewbrinda/Desktop/Intake.csv')
Diversion_Data = pd.read_csv('/Users/drewbrinda/Desktop/Diversion.csv')
Initiation_Data = pd.read_csv('/Users/drewbrinda/Desktop/Initiation.csv')
# Out:
# /Users/drewbrinda/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (10,11,14,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/drewbrinda/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (9,10,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Sentencing_Data.head()
# Out:
#         CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE OFFENSE_CATEGORY  \
# 0  123687096003         726349489296  06/09/2013 12:00:00 AM   Aggravated DUI
# 1  123687186464         726350563707  08/21/2013 12:00:00 AM        Narcotics
# 2  123687231695         726350921844  08/21/2013 12:00:00 AM        Narcotics
# 3  123687231695         727551755091  08/21/2013 12:00:00 AM        Narcotics
# 4  123687276925         726351279981  08/21/2013 12:00:00 AM        Narcotics
#
#    PRIMARY_CHARGE_FLAG     CHARGE_ID  CHARGE_VERSION_ID  \
# 0                 True  555439048433       547480844004
# 1                 True  555249567063       539997943037
# 2                 True  556594592586       541322455862
# 3                 True  556594592586       541322455862
# 4                 True  555249492140       539997870294
#
#                    DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 0                        DRIVING UNDER THE INFLUENCE             1
# ...

# %%
Intake_Data.head()
# Out:
#        CASE_ID  CASE_PARTICIPANT_ID RECEIVED_DATE   OFFENSE_CATEGORY  \
# 0  67119486014         198620523123    05/24/2011  PROMIS Conversion
# 1  67119486014         198620612657    05/24/2011  PROMIS Conversion
# 2  67119486014         198620702192    05/24/2011  PROMIS Conversion
# 3  68816942646         207813003704    01/27/2012  PROMIS Conversion
# 4  72968472250         207597852922    01/31/2011  PROMIS Conversion
#
#         PARTICIPANT_STATUS  AGE_AT_INCIDENT      RACE GENDER INCIDENT_CITY  \
# 0  Continued Investigation             25.0     Black   Male           NaN
# 1                 Approved             22.0     Black   Male           NaN
# 2  Continued Investigation             19.0     Black   Male           NaN
# 3                 Approved              NaN     Black   Male           NaN
# 4                 Approved             37.0  HISPANIC   Male           NaN
#
#   INCIDENT_BEGIN_DATE INCIDENT_END_DATE  LAW_ENFORCEMENT_AGENCY  \
# ...

# %%
Sentencing_Data.count()
# Out:
# CASE_ID                              266042
# CASE_PARTICIPANT_ID                  266042
# RECEIVED_DATE                        266042
# OFFENSE_CATEGORY                     266042
# PRIMARY_CHARGE_FLAG                  266042
# CHARGE_ID                            266042
# CHARGE_VERSION_ID                    266042
# DISPOSITION_CHARGED_OFFENSE_TITLE    266042
# CHARGE_COUNT                         266042
# DISPOSITION_DATE                     266042
# DISPOSITION_CHARGED_CHAPTER          266042
# DISPOSITION_CHARGED_ACT              260650
# DISPOSITION_CHARGED_SECTION          260650
# DISPOSITION_CHARGED_CLASS            266023
# DISPOSITION_CHARGED_AOIC             266018
# CHARGE_DISPOSITION                   266042
# CHARGE_DISPOSITION_REASON              1096
# SENTENCE_JUDGE                       265300
# SENTENCE_COURT_NAME                  264653
# SENTENCE_COURT_FACILITY              263979
# SENTENCE_PHASE                       266042
# ...

# %%
Sentencing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266042 entries, 0 to 266041
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   CASE_ID                            266042 non-null  int64
#  1   CASE_PARTICIPANT_ID                266042 non-null  int64
#  2   RECEIVED_DATE                      266042 non-null  object
#  3   OFFENSE_CATEGORY                   266042 non-null  object
#  4   PRIMARY_CHARGE_FLAG                266042 non-null  bool
#  5   CHARGE_ID                          266042 non-null  int64
#  6   CHARGE_VERSION_ID                  266042 non-null  int64
#  7   DISPOSITION_CHARGED_OFFENSE_TITLE  266042 non-null  object
#  8   CHARGE_COUNT                       266042 non-null  int64
#  9   DISPOSITION_DATE                   266042 non-null  object
#  10  DISPOSITION_CHARGED_CHAPTER        266042 non-null  object
# ...

# %%
Sentencing_Data.describe()
# Out:
#             CASE_ID  CASE_PARTICIPANT_ID     CHARGE_ID  CHARGE_VERSION_ID  \
# count  2.660420e+05         2.660420e+05  2.660420e+05       2.660420e+05
# mean   1.238684e+11         7.285245e+11  5.622426e+11       5.513269e+11
# std    1.242184e+10         1.216376e+11  8.596735e+10       8.291001e+10
# min    4.612700e+10         9.179722e+10  7.527258e+10       7.309481e+10
# 25%    1.207901e+11         7.000388e+11  5.322376e+11       5.193653e+11
# 50%    1.254600e+11         7.434503e+11  5.692824e+11       5.564968e+11
# 75%    1.303604e+11         7.914141e+11  6.118509e+11       6.000515e+11
# max    1.387342e+11         8.743884e+11  6.817630e+11       6.655184e+11
#
#         CHARGE_COUNT  LENGTH_OF_CASE_in_Days  AGE_AT_INCIDENT
# count  266042.000000           247304.000000    262390.000000
# mean        2.135005              328.734889        32.353615
# std         4.402440             2813.810681        11.767673
# ...

# %%
sns.heatmap(Sentencing_Data.corr())
# Out:
# <AxesSubplot:>

# %%
df= Intake_Data["AGE_AT_INCIDENT"].value_counts()

# %%
df
# Out:
# 19.0     19041
# 20.0     18668
# 21.0     18585
# 22.0     18178
# 23.0     18070
#          ...
# 87.0         1
# 130.0        1
# 129.0        1
# 105.0        1
# 215.0        1
# Name: AGE_AT_INCIDENT, Length: 103, dtype: int64

# %%
df.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
count_classes = pd.value_counts(Intake_Data['RACE'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Race arrests histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(Intake_Data['GENDER'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Gender Arrests")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.boxplot(Intake_Data['AGE_AT_INCIDENT'])
# Out:
# /Users/drewbrinda/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AGE_AT_INCIDENT'>

# %%
Intake_Data.groupby(['RACE','GENDER']).mean()
# Out:
#                                                                   CASE_ID  \
# RACE                             GENDER
# ASIAN                            Female                      1.210234e+11
#                                  Male                        1.270304e+11
# Albino                           Female                      1.209974e+11
# American Indian                  Female                      1.262775e+11
#                                  Male                        1.271290e+11
# Asian                            Female                      1.278609e+11
#                                  Male                        1.282913e+11
# Biracial                         Female                      1.275440e+11
#                                  Male                        1.272291e+11
# Black                            Female                      1.276871e+11
#                                  Male                        1.282174e+11
# ...

# %%
Diversion_Data.head(100)
# Out:
#          CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0   117861448721         674290699882  01/01/2011 12:00:00 AM
# 1   117861448721         674290699882  01/01/2011 12:00:00 AM
# 2   117862443793         674299653306  01/02/2011 12:00:00 AM
# 3   117863710247         674310576484  01/03/2011 12:00:00 AM
# 4   117863710247         674310666018  01/03/2011 12:00:00 AM
# ..           ...                  ...                     ...
# 95  117987868058         675425367326  01/23/2011 12:00:00 AM
# 96  117988456055         675431276586  01/24/2011 12:00:00 AM
# 97  117995150173         675493234281  01/23/2011 12:00:00 AM
# 98  117999266152         675529585183  01/23/2011 12:00:00 AM
# 99  117999492304         675532718881  01/25/2011 12:00:00 AM
#
#                       OFFENSE_CATEGORY DIVERSION_PROGRAM  \
# 0                         Retail Theft                DS
# 1                         Retail Theft                VC
# ...

# %%
df2= Diversion_Data["DIVERSION_RESULT"].value_counts()

# %%
df2
# Out:
# Graduated    13943
# Failed        4064
# Name: DIVERSION_RESULT, dtype: int64

# %%
# Get only the object columns

obj_cols = list(Diversion_Data.columns)

obj_cols

 

#Import LabelEncoder

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() 

#Create df to populate with encoded values

encoded_obj_df = pd.DataFrame(columns=obj_cols)

#Apply the transformer

for col in obj_cols:

  encoded_obj_df[col] = le.fit_transform(Diversion_Data[col])


encoded_obj_df.head(10)
# Out:
#    CASE_ID  CASE_PARTICIPANT_ID  RECEIVED_DATE  OFFENSE_CATEGORY  \
# 0        0                    0              0                45
# 1        0                    0              0                45
# 2        1                    1              7                45
# 3        2                    2             15                34
# 4        2                    3             15                34
# 5        3                    4             15                34
# 6        4                    5             15                34
# 7        5                    6             15                34
# 8        6                    7              0                34
# 9        7                    8              7                34
#
#    DIVERSION_PROGRAM  REFERRAL_DATE  DIVERSION_COUNT  \
# 0                  5           1375                1
# 1                  9           1807                0
# 2                  6           2090                0
# ...

# %%
count_classes2 = pd.value_counts(Diversion_Data["DIVERSION_RESULT"], sort = True).sort_index()
count_classes2.plot(kind = 'bar')
plt.title("Graduated vs Not")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes3 = pd.value_counts(Diversion_Data["OFFENSE_CATEGORY"], sort = True).sort_index().head(10)
count_classes3.plot(kind = 'bar')
plt.title("Offense")
plt.xlabel("OFFENSE_CATEGORY")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
Initiation_Data.head(100)
# Out:
#         CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0   67119486014         198620523123  05/24/2011 12:00:00 AM
# 1   67119486014         198620612657  05/24/2011 12:00:00 AM
# 2   67119486014         198620612657  05/24/2011 12:00:00 AM
# 3   67119486014         198620612657  05/24/2011 12:00:00 AM
# 4   67119486014         198620612657  05/24/2011 12:00:00 AM
# ..          ...                  ...                     ...
# 95  67119486014         198620612657  05/24/2011 12:00:00 AM
# 96  67119486014         198620612657  05/24/2011 12:00:00 AM
# 97  67119486014         198620612657  05/24/2011 12:00:00 AM
# 98  67119486014         198620612657  05/24/2011 12:00:00 AM
# 99  67119486014         198620612657  05/24/2011 12:00:00 AM
#
#      OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG     CHARGE_ID  CHARGE_VERSION_ID  \
# 0   PROMIS Conversion                 True  383674823800       339800972000
# 1   PROMIS Conversion                False  516038461779       501429727009
# ...

# %%
count_classes4 = pd.value_counts(Initiation_Data["CHARGE_OFFENSE_TITLE"], sort = True).sort_index().head(10)
count_classes4.plot(kind = 'bar')
plt.title("Offense")
plt.xlabel("OFFENSE_CATEGORY")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes5 = pd.value_counts(Sentencing_Data["INCIDENT_CITY"], sort = True).sort_index().head(10)
count_classes5.plot(kind = 'bar')
plt.title("City Incidents")
plt.xlabel("City Name")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
